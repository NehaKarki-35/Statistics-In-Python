# %% [markdown]
# # MEASURES OF DISPERSION

# %% [markdown]
# - The meassure of dispersion is an index which quantifies the degree to which he data is dispersed or spread.
# - It serves as the measure of the realiability of the avarage.

# %% [markdown]
# # Use of the measures of dispersion

# %% [markdown]
# - it shows the variation in the data that provides information such as how well the average of the sample represents the entire data.less variation
# gives close represntation while with larger variation ,the average may not closely represnt all he values in the sample.

# %% [markdown]
# - it enables us to compare two or more serious with regard to their variations . it helps to determine consistency.

# %% [markdown]
# - it also helps o control the causes behind the variations.

# %% [markdown]
# ## scale of measures
# Range, Interquartile range, Standard Deviation , Variance

# %% [markdown]
# ## Range

# %% [markdown]
# - Range is the diference between the largest and smallest data point in the set.
# - Range = M aximum value - Minimum value
# - For our previous example

# %% [markdown]
# - mean of player1=15 (5,15,15,25)
# - mean of player2=15(10,15,25,20)
#
# - Range of player1= 25-5 =20
# - Range of player2= 20-10=10
