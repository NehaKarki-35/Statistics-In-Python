# %% [markdown]
# # The Key Sources Of Data Include:

# %% [markdown]
# ## PRIMARY

# %% [markdown]
# ***This type of data is collected firsthand by the researcher for a specific purpose. It involves direct interaction with the source or subjects of the study. Examples of primary data collection methods include surveys, interviews, experiments, observations, and focus groups.***

# %% [markdown]
# ## SECONDARY

# %% [markdown]
# ***Secondary data, on the other hand, refers to data that has already been collected by someone else for a purpose other than the current research study.***
#
# . Government
#
# . Industries
#
# . Individual Bodies

# %% [markdown]
# # Descriptive statistics

# %% [markdown]
# ***Descriptie statistics referes to the method of statistics that inolves summarizing ,organzing ,and presenting data meaningfully and concisely***

# %% [markdown]
# # what is Data?

# %% [markdown]
# ***Data refers to information or obserations that are collected ,recorded, or analyzed to draw conclusions ,make inferences ,or support decision making.***

# %% [markdown]
# Types of Data
# ## Categorial data
# ***Categorial data represnts groups or categories.***
# -  1. car brand:audi,bmw
# -  2. yes/no
# ## Numerical data
# ***Numerical data represnts numbers example:***
# -  1. student marks
# -  2. income

# %% [markdown]
# # NUMERICAL DATA

# %% [markdown]
# # DISCRETE DATA
# ***Specific,distinct alues and are counted in individual units the values are often integers and are sperated from each other.***
# ## eg.number of children
# ## numbers of book library

# %% [markdown]
# # continous data

# %% [markdown]
# ***continous data can take on any alue within a giin range.***
# ## eg. Height 176.5
# ## Monthly EXP rs.1200034.44

# %% [markdown]
# ## Measures of central Tendency
# -  ***. Central tendency is  a way to describe the center or typical value of a set of numbers .It giives you a sense of where most of the data is concerated.***
# - ***.You can make sense of the data without looking at all the values or obserations by just looking at the central tendency.***
# - ***. A meansure of central tendancy is a summary measure of your column.***

# %% [markdown]
# # There have been sereral measures of central tendency developed in statistical theory .The most commonly used ones include
# - . Mean or arthmetic mean
# - . Median
# - . Mode

# %% [markdown]
# # Median
# - it can be calculated by arranging alues in either ascending or descending order and then finding the middle value.
# - for odd numbers of values:
# -               Median = [(n + 1)/2]th term
# - for een number of values:
# -               Median =
